# %% [markdown]
# ### Задача
#
# 1. Оценить количество ботов, которые заходят на наш сайт, и их долю от всего трафика.
#
# 2. Определить, с каких источников и в какое время суток чаще всего заходят роботы.

# %%
# импортируем все библиотеки
import json # расшифровка json
import requests # запросы
import pandas as pd
from pprint import pprint # красивый принт

# %% [markdown]
# #### Получаем данные

# %%
token = '<ваш_токен>' # вместо слов "ваш_токен" нужно вставить свой токен «Яндекс.Метрики»

headers = {'Authorization': 'OAuth ' + token} #собераем headers

# %%
params = {'metrics': 'ym:s:visits,ym:s:robotPercentage', # метрика ym:s:visits визиты и ym:s:robotPercentage процент роботов
          'dimensions': 'ym:s:lastsignTrafficSource,ym:s:hour', # групировки ym:s:lastsignTrafficSource источники трафика
          'date1': '2020-09-01',                                 # по атрибуции последний значимый источник и часам ym:s:hour
          'date2': '2020-09-30',  # данные за сентябрь указано в Задание 9.7.1. в тестовом диалоге 
          'ids': 30177909,
          'accuracy':'full',
          'limit':100000}

# %%
response = requests.get('https://api-metrika.yandex.net/stat/v1/data', params=params, headers=headers) # запрос при помощи библиотеки requests
print (response.status_code) # проверяем статус, у мнения точно 200
# Out:
# 200

# %% [markdown]
# #### Преобразования таблиц и типов данных

# %%
metrika_data = response.json() # преобразовываем json словарь из словарей

# %%
pprint(metrika_data) # просто проверка ,что всё нормально
# Out:
# {'contains_sensitive_data': False,
#  'data': [{'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '16', 'name': '16:00'}],
#            'metrics': [251.0, 24.70119522]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '15', 'name': '15:00'}],
#            'metrics': [240.0, 26.25]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '11', 'name': '11:00'}],
#            'metrics': [228.0, 25.87719298]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '13', 'name': '13:00'}],
#            'metrics': [227.0, 28.1938326]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '12', 'name': '12:00'}],
#            'metrics': [225.0, 24.88888889]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '14', 'name': '14:00'}],
#            'metrics': [225.0, 25.77777778]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '17', 'name': '17:00'}],
#            'metrics': [209.0, 26.31578947]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '10', 'name': '10:00'}],
#            'metrics': [186.0, 19.35483871]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '21', 'name': '21:00'}],
#            'metrics': [166.0, 17.46987952]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '19', 'name': '19:00'}],
#            'metrics': [161.0, 23.60248447]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '20', 'name': '20:00'}],
#            'metrics': [157.0, 16.56050955]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '22', 'name': '22:00'}],
#            'metrics': [149.0, 20.13422819]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '9', 'name': '09:00'}],
#            'metrics': [147.0, 24.48979592]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '18', 'name': '18:00'}],
#            'metrics': [143.0, 21.67832168]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '8', 'name': '08:00'}],
#            'metrics': [128.0, 22.65625]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '23', 'name': '23:00'}],
#            'metrics': [125.0, 16.8]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '0', 'name': '00:00'}],
#            'metrics': [102.0, 16.66666667]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '14', 'name': '14:00'}],
#            'metrics': [65.0, 21.53846154]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '12', 'name': '12:00'}],
#            'metrics': [61.0, 24.59016393]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '7', 'name': '07:00'}],
#            'metrics': [61.0, 9.83606557]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '21', 'name': '21:00'}],
#            'metrics': [53.0, 24.52830189]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '1', 'name': '01:00'}],
#            'metrics': [53.0, 15.09433962]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '18', 'name': '18:00'}],
#            'metrics': [46.0, 19.56521739]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '10', 'name': '10:00'}],
#            'metrics': [43.0, 20.93023256]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '11', 'name': '11:00'}],
#            'metrics': [43.0, 18.60465116]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '16', 'name': '16:00'}],
#            'metrics': [42.0, 19.04761905]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '15', 'name': '15:00'}],
#            'metrics': [41.0, 14.63414634]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '2', 'name': '02:00'}],
#            'metrics': [41.0, 12.19512195]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '19', 'name': '19:00'}],
#            'metrics': [40.0, 25.0]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '17', 'name': '17:00'}],
#            'metrics': [39.0, 23.07692308]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '9', 'name': '09:00'}],
#            'metrics': [37.0, 32.43243243]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '20', 'name': '20:00'}],
#            'metrics': [34.0, 23.52941176]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '6', 'name': '06:00'}],
#            'metrics': [34.0, 8.82352941]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '22', 'name': '22:00'}],
#            'metrics': [33.0, 18.18181818]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '13', 'name': '13:00'}],
#            'metrics': [32.0, 40.625]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '3', 'name': '03:00'}],
#            'metrics': [28.0, 10.71428571]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '23', 'name': '23:00'}],
#            'metrics': [27.0, 29.62962963]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '5', 'name': '05:00'}],
#            'metrics': [25.0, 4.0]},
#           {'dimensions': [{'icon_id': '2',
#                            'icon_type': 'traffic-source',
#                            'id': 'organic',
#                            'name': 'Search engine traffic'},
#                           {'id': '4', 'name': '04:00'}],
#            'metrics': [23.0, 13.04347826]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '8', 'name': '08:00'}],
#            'metrics': [21.0, 23.80952381]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '7', 'name': '07:00'}],
#            'metrics': [19.0, 26.31578947]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '1', 'name': '01:00'}],
#            'metrics': [16.0, 25.0]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '5', 'name': '05:00'}],
#            'metrics': [15.0, 20.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '16', 'name': '16:00'}],
#            'metrics': [14.0, 21.42857143]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '15', 'name': '15:00'}],
#            'metrics': [12.0, 8.33333333]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '2', 'name': '02:00'}],
#            'metrics': [11.0, 18.18181818]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '6', 'name': '06:00'}],
#            'metrics': [11.0, 27.27272727]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '12', 'name': '12:00'}],
#            'metrics': [11.0, 18.18181818]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '0', 'name': '00:00'}],
#            'metrics': [10.0, 20.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '10', 'name': '10:00'}],
#            'metrics': [10.0, 60.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '17', 'name': '17:00'}],
#            'metrics': [10.0, 20.0]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '3', 'name': '03:00'}],
#            'metrics': [9.0, 22.22222222]},
#           {'dimensions': [{'icon_id': '0',
#                            'icon_type': 'traffic-source',
#                            'id': 'direct',
#                            'name': 'Direct traffic'},
#                           {'id': '4', 'name': '04:00'}],
#            'metrics': [9.0, 33.33333333]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '9', 'name': '09:00'}],
#            'metrics': [9.0, 11.11111111]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '9', 'name': '09:00'}],
#            'metrics': [8.0, 12.5]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '21', 'name': '21:00'}],
#            'metrics': [8.0, 12.5]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '11', 'name': '11:00'}],
#            'metrics': [7.0, 42.85714286]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '13', 'name': '13:00'}],
#            'metrics': [7.0, 14.28571429]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '20', 'name': '20:00'}],
#            'metrics': [7.0, 28.57142857]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '13', 'name': '13:00'}],
#            'metrics': [7.0, 28.57142857]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '21', 'name': '21:00'}],
#            'metrics': [6.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '19', 'name': '19:00'}],
#            'metrics': [6.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '22', 'name': '22:00'}],
#            'metrics': [6.0, 50.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '14', 'name': '14:00'}],
#            'metrics': [5.0, 40.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '18', 'name': '18:00'}],
#            'metrics': [5.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '20', 'name': '20:00'}],
#            'metrics': [5.0, 0.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '6', 'name': '06:00'}],
#            'metrics': [4.0, 50.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '8', 'name': '08:00'}],
#            'metrics': [4.0, 25.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '18', 'name': '18:00'}],
#            'metrics': [4.0, 25.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '6', 'name': '06:00'}],
#            'metrics': [4.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '15', 'name': '15:00'}],
#            'metrics': [4.0, 25.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '0', 'name': '00:00'}],
#            'metrics': [3.0, 0.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '7', 'name': '07:00'}],
#            'metrics': [3.0, 33.33333333]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '8', 'name': '08:00'}],
#            'metrics': [3.0, 33.33333333]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '12', 'name': '12:00'}],
#            'metrics': [3.0, 33.33333333]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '14', 'name': '14:00'}],
#            'metrics': [3.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '23', 'name': '23:00'}],
#            'metrics': [3.0, 0.0]},
#           {'dimensions': [{'icon_id': '-1',
#                            'icon_type': 'traffic-source',
#                            'id': 'internal',
#                            'name': 'Internal traffic'},
#                           {'id': '9', 'name': '09:00'}],
#            'metrics': [2.0, 50.0]},
#           {'dimensions': [{'icon_id': '-1',
#                            'icon_type': 'traffic-source',
#                            'id': 'internal',
#                            'name': 'Internal traffic'},
#                           {'id': '12', 'name': '12:00'}],
#            'metrics': [2.0, 50.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '1', 'name': '01:00'}],
#            'metrics': [2.0, 0.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '2', 'name': '02:00'}],
#            'metrics': [2.0, 0.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '19', 'name': '19:00'}],
#            'metrics': [2.0, 0.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '22', 'name': '22:00'}],
#            'metrics': [2.0, 50.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '23', 'name': '23:00'}],
#            'metrics': [2.0, 50.0]},
#           {'dimensions': [{'icon_id': '4',
#                            'icon_type': 'traffic-source',
#                            'id': 'saved',
#                            'name': 'Cached page traffic'},
#                           {'id': '1', 'name': '01:00'}],
#            'metrics': [2.0, 50.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '5', 'name': '05:00'}],
#            'metrics': [2.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '7', 'name': '07:00'}],
#            'metrics': [2.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '11', 'name': '11:00'}],
#            'metrics': [2.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '16', 'name': '16:00'}],
#            'metrics': [2.0, 50.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '17', 'name': '17:00'}],
#            'metrics': [2.0, 0.0]},
#           {'dimensions': [{'icon_id': '-1',
#                            'icon_type': 'traffic-source',
#                            'id': 'internal',
#                            'name': 'Internal traffic'},
#                           {'id': '2', 'name': '02:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '-1',
#                            'icon_type': 'traffic-source',
#                            'id': 'internal',
#                            'name': 'Internal traffic'},
#                           {'id': '8', 'name': '08:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '-1',
#                            'icon_type': 'traffic-source',
#                            'id': 'internal',
#                            'name': 'Internal traffic'},
#                           {'id': '11', 'name': '11:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '-1',
#                            'icon_type': 'traffic-source',
#                            'id': 'internal',
#                            'name': 'Internal traffic'},
#                           {'id': '14', 'name': '14:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '-1',
#                            'icon_type': 'traffic-source',
#                            'id': 'internal',
#                            'name': 'Internal traffic'},
#                           {'id': '16', 'name': '16:00'}],
#            'metrics': [1.0, 100.0]},
#           {'dimensions': [{'icon_id': '-1',
#                            'icon_type': 'traffic-source',
#                            'id': 'internal',
#                            'name': 'Internal traffic'},
#                           {'id': '17', 'name': '17:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '1',
#                            'icon_type': 'traffic-source',
#                            'id': 'referral',
#                            'name': 'Link traffic'},
#                           {'id': '3', 'name': '03:00'}],
#            'metrics': [1.0, 100.0]},
#           {'dimensions': [{'icon_id': '4',
#                            'icon_type': 'traffic-source',
#                            'id': 'saved',
#                            'name': 'Cached page traffic'},
#                           {'id': '8', 'name': '08:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '4',
#                            'icon_type': 'traffic-source',
#                            'id': 'saved',
#                            'name': 'Cached page traffic'},
#                           {'id': '11', 'name': '11:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '4',
#                            'icon_type': 'traffic-source',
#                            'id': 'saved',
#                            'name': 'Cached page traffic'},
#                           {'id': '12', 'name': '12:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '4',
#                            'icon_type': 'traffic-source',
#                            'id': 'saved',
#                            'name': 'Cached page traffic'},
#                           {'id': '17', 'name': '17:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '1', 'name': '01:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '2', 'name': '02:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '4', 'name': '04:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '8',
#                            'icon_type': 'traffic-source',
#                            'id': 'social',
#                            'name': 'Social network traffic'},
#                           {'id': '10', 'name': '10:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '9',
#                            'icon_type': 'traffic-source',
#                            'id': 'recommend',
#                            'name': 'Recommendation system traffic'},
#                           {'id': '8', 'name': '08:00'}],
#            'metrics': [1.0, 0.0]},
#           {'dimensions': [{'icon_id': '9',
#                            'icon_type': 'traffic-source',
#                            'id': 'recommend',
#                            'name': 'Recommendation system traffic'},
#                           {'id': '14', 'name': '14:00'}],
#            'metrics': [1.0, 0.0]}],
#  'data_lag': 158,
#  'max': [251.0, 100.0],
#  'min': [1.0, 0.0],
#  'query': {'adfox_event_id': '0',
#            'attr_name': '',
#            'attribution': 'LastSign',
#            'auto_group_size': '1',
#            'currency': 'RUB',
#            'date1': '2020-09-01',
#            'date2': '2020-09-30',
#            'dimensions': ['ym:s:lastsignTrafficSource', 'ym:s:hour'],
#            'group': 'Week',
#            'ids': [30177909],
#            'limit': 100000,
#            'metrics': ['ym:s:visits', 'ym:s:robotPercentage'],
#            'offline_window': '21',
#            'offset': 1,
#            'quantile': '50',
#            'sort': ['-ym:s:visits']},
#  'sample_share': 1.0,
#  'sample_size': 4315,
#  'sample_space': 4315,
#  'sampled': False,
#  'total_rows': 107,
#  'total_rows_rounded': False,
#  'totals': [4315.0, 22.29432213]}

# %%
def getMetrikaDataInListOfDicts(metrika_data): # функция анпакинга структуры json в приемлемый для pandas вариант
    list_of_dicts = [] # список для добавления данных
    dimensions_list = metrika_data['query']['dimensions'] # список групировок 
    metrics_list = metrika_data['query']['metrics'] # список метрк
    for data_item in metrika_data['data']: # цыкл по основным данным 
        d = {} # временный словарь 
        for i,dimension in enumerate(data_item['dimensions']): # цыкл для групировок
            d[dimensions_list[i]] = dimension['name'] # добавление к временному словарю
        for i,metric in enumerate(data_item['metrics']): # цыкл для метрик
            d[metrics_list[i]] = metric # добавление к временному словарю
        list_of_dicts.append(d) #  добавление временного словаря в список
    return list_of_dicts

# %%
metrika_list_of_dicts = getMetrikaDataInListOfDicts(metrika_data) # передаём в функцию структуре json

# %% [markdown]
# ### Преобразование типов

# %%
for i in metrika_list_of_dicts: # цыкл преобразования типов
    i['ym:s:visits']=int(i['ym:s:visits']) # int

# %% [markdown]
# ### Основная таблица

# %%
metrika_df = pd.DataFrame(metrika_list_of_dicts) # создание датафрейма 
metrika_df.columns=['Source','Hour','Visits','Robot%'] # преименование столбцов 
metrika_df['RobotCount'] = (metrika_df['Visits']/100)*metrika_df['Robot%'] # приблизительное число роботов
metrika_df['RobotCount'] = metrika_df['RobotCount'].apply(lambda x: int(x)) # цыкл преобразования типов
display(metrika_df.head(10))
# Out:
#                   Source   Hour  Visits     Robot%  RobotCount
# 0  Search engine traffic  16:00     251  24.701195          62
# 1  Search engine traffic  15:00     240  26.250000          63
# 2  Search engine traffic  11:00     228  25.877193          58
# 3  Search engine traffic  13:00     227  28.193833          64
# 4  Search engine traffic  12:00     225  24.888889          56
# 5  Search engine traffic  14:00     225  25.777778          58
# 6  Search engine traffic  17:00     209  26.315789          54
# 7  Search engine traffic  10:00     186  19.354839          36
# 8  Search engine traffic  21:00     166  17.469880          29
# 9  Search engine traffic  19:00     161  23.602484          37

# %% [markdown]
# #### 1. Оценить количество ботов, которые заходят на наш сайт, и их долю от всего трафика.

# %%
print('{} общее количество визитов'.format(metrika_df['Visits'].sum())) # общее количество визитов
print('{} общее приблизительное количество роботов'.format(metrika_df['RobotCount'].sum()) ) # общее приблизительное количество роботов(полученное из процента)
print('{} средний процент роботов'.format(metrika_df['Robot%'].mean())) # средний процент роботов
# Out:
# 4315 общее количество визитов
# 932 общее приблизительное количество роботов
# 19.81789199738318 средний процент роботов

# %% [markdown]
# Процент роботов в среднем, по потокам почти достиг 1/5 всего трафика сайта. Это не совсем плохой показатель, но требуется улучшения и установка более современного "ПО" по блокировке сеансов с роботами и подозрительными запросами.

# %% [markdown]
# #### 2. Определить, с каких источников и в какое время суток чаще всего заходят роботы.

# %% [markdown]
# #### Пропуски: обработаны при помощи "fill_value=0" - замена всех пропусков на ноль

# %%
# сводная таблица
metrika_df.pivot_table(values=['Robot%','Visits'], index='Source',aggfunc='mean',fill_value=0) # "fill_value=0" - замена всех пропусков на ноль
# Out:
#                                   Robot%      Visits
# Source
# Cached page traffic            10.000000    1.200000
# Direct traffic                 23.835393   31.541667
# Internal traffic               25.000000    1.250000
# Link traffic                   27.249606    5.727273
# Recommendation system traffic   0.000000    1.000000
# Search engine traffic          18.963520  138.916667
# Social network traffic         11.084055    3.636364

# %% [markdown]
# Лидеры по трафику ботов: прямые ссылки(Link traffic) и Internal traffic за ними переходы по рекламе(Direct) также трафик с поисковых систем(Search engine).

# %%
# сводная таблица
metrika_df.pivot_table(values='Visits', index='Source',aggfunc='sum',fill_value=0) # "fill_value=0" - замена всех пропусков на ноль
# Out:
#                                Visits
# Source
# Cached page traffic                 6
# Direct traffic                    757
# Internal traffic                   10
# Link traffic                      126
# Recommendation system traffic       2
# Search engine traffic            3334
# Social network traffic             80

# %% [markdown]
# Берём 3 самых репрезентативных источника: Direct traffic, Link traffic, Search engine traffic.

# %% [markdown]
# Search engine traffic повышение активности ботов явно просматривается с 80:00 до 19:00. С пиками в 13:00 и 17:00. и всплеском в 22:00

# %%
# сводная таблица Search engine traffic 
metrika_df.pivot_table(index='Hour',columns='Source',values=['Robot%','Visits'],fill_value=0)['Robot%'][['Search engine traffic']]
# Out:
# Source  Search engine traffic
# Hour
# 00:00               16.666667
# 01:00               15.094340
# 02:00               12.195122
# 03:00               10.714286
# 04:00               13.043478
# 05:00                4.000000
# 06:00                8.823529
# 07:00                9.836066
# 08:00               22.656250
# 09:00               24.489796
# 10:00               19.354839
# 11:00               25.877193
# 12:00               24.888889
# 13:00               28.193833
# 14:00               25.777778
# 15:00               26.250000
# 16:00               24.701195
# 17:00               26.315789
# 18:00               21.678322
# 19:00               23.602484
# 20:00               16.560510
# 21:00               17.469880
# 22:00               20.134228
# 23:00               16.800000

# %% [markdown]
# Link traffic довольно мало переходов вообще, но из них рекордные 27% не живого трафика. Данные не постоянны и можно заключить, что ссылки используют чаше как раз для парсинга. Стоит установить отдельный фильтр для подобных запросов на сервер сайта.

# %%
# сводная таблица Link traffic
metrika_df.pivot_table(index='Hour',columns='Source',values=['Robot%','Visits'],fill_value=0)['Robot%'][['Link traffic']]
# Out:
# Source  Link traffic
# Hour
# 00:00       0.000000
# 01:00       0.000000
# 02:00       0.000000
# 03:00     100.000000
# 04:00       0.000000
# 05:00       0.000000
# 06:00      50.000000
# 07:00      33.333333
# 08:00      25.000000
# 09:00      12.500000
# 10:00      60.000000
# 11:00      42.857143
# 12:00      18.181818
# 13:00      14.285714
# 14:00      40.000000
# 15:00       8.333333
# 16:00      21.428571
# 17:00      20.000000
# 18:00      25.000000
# 19:00       0.000000
# 20:00      28.571429
# 21:00       0.000000
# 22:00      50.000000
# 23:00      50.000000

# %% [markdown]
# Direct traffic данные достаточно не стабильны, есть пик в 13:00 в 40.6% что много, и весомо вредит, и более не выраженные, но всё еще высокие в 04:00, 09:00, 23:00.

# %%
# сводная таблица Direct traffic
metrika_df.pivot_table(index='Hour',columns='Source',values=['Robot%','Visits'],fill_value=0)['Robot%'][['Direct traffic']]
# Out:
# Source  Direct traffic
# Hour
# 00:00        20.000000
# 01:00        25.000000
# 02:00        18.181818
# 03:00        22.222222
# 04:00        33.333333
# 05:00        20.000000
# 06:00        27.272727
# 07:00        26.315789
# 08:00        23.809524
# 09:00        32.432432
# 10:00        20.930233
# 11:00        18.604651
# 12:00        24.590164
# 13:00        40.625000
# 14:00        21.538462
# 15:00        14.634146
# 16:00        19.047619
# 17:00        23.076923
# 18:00        19.565217
# 19:00        25.000000
# 20:00        23.529412
# 21:00        24.528302
# 22:00        18.181818
# 23:00        29.629630

# %% [markdown]
# #### Вывод

# %% [markdown]
# Трафик ботов не стабилен и зависит от источника. Сервер слабо прерывает такого рода трафик в случаях когда он переваливает на пиках почти за треть всех запросов, "ПО" сервера рекомендованною оснастить защитой, и массовыми проверками при помощи капчи.
